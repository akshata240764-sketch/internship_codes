# %%
name="akshata"
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# True

# %% [markdown]
# name.istitle()

# %%
name.istitle()
# Out:
# False

# %%
name1="ok"
name2="123"
name3="ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name="akshata"

# %%
name.startswith("a")
# Out:
# True

# %%
name.endswith("a")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'akshata'

# %%
name.rstrip()
# Out:
# 'akshata'

# %%
name1=" akshata "

# %%
name1.lstrip()
# Out:
# 'akshata '

# %%
name1.rstrip()
# Out:
# ' akshata'

# %%
name1.strip()
# Out:
# 'akshata'

# %%
len(name1)
# Out:
# 9

# %%
name1.replace("a","w")
# Out:
# ' wkshwtw '

# %%
a=9
b=6

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 3

# %%
a/b
# Out:
# 1.5

# %%
a**b
# Out:
# 531441

# %%
b//a
# Out:
# 0

# %%
b%a
# Out:
# 6

# %%
z=2
z+2
# Out:
# 4

# %%
z+=3

# %%
z
# Out:
# 5

# %%
z-=2

# %%
z
# Out:
# 3

# %%
z*=4
z
# Out:
# 12

# %%
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
a=True
b=False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
a=5
b=5

# %%
id(a),id(b)
# Out:
# (140730847036456, 140730847036456)

# %%
a is b
# Out:
# True

# %%
a=[3,4]
b=[3,4]

# %%
id(a),id(b)
# Out:
# (1546223298048, 1546223294016)

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
z=a

# %%
a.append(10)

# %%
z
# Out:
# [3, 4, 10]

# %%
l=[1,2,3,4]

# %%
1 in l
# Out:
# True

# %%
5 not in l
# Out:
# True

# %%
5+2-10
# Out:
# -3

# %%
(4-2)**2
# Out:
# 4

# %%
2**2**3
# Out:
# 256

# %%
2**3/2
# Out:
# 4.0

# %%
name="geet"
marks=76.57

# %%
print("my name is",name,"and marks are ",marks)
# Out:
# my name is geet and marks are  76.57

# %%
print("my name is %s and marks are %i"%(name,marks))
# Out:
# my name is geet and marks are 76

# %% [markdown]
# akshata

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is geet and marks are 76.57

# %% [markdown]
# dir and help

# %%
dir
# Out:
# <function dir>

# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
ord('a')
# Out:
# 97

# %%
chr(65)
# Out:
# 'A'

# %%
num1=34
num2=44.56
num3="ok"
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num2)
# Out:
# '44.56'

# %%
str(num1)
# Out:
# '34'

# %%
a=(int(input("enter a:")))
b=(int(input("enter b:")))
print(a+b)
# Out:
# enter a: 1
# enter b: 2
# 3
