# %% [raw]
# print("hello world")

# %%
print("hello world")

# %%
print('hello world')

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# identifiers

# %% [raw]
# identifiers

# %%
num=87

# %%
num1=90

# %%
name="riya"

# %%
print(name)
# Out:
# riya

# %%
name
# Out:
# 'riya'

# %%
a=23

# %%
b=23.4

# %%
c="akshata"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
num=23e4
type(num)
num
# Out:
# 230000.0

# %%
sent='i "like" python programming'

# %%
sent
# Out:
# 'i "like" python programming'

# %%
sent="i like 'python' programming"

# %%
sent
# Out:
# "i like 'python' programming"

# %%
a=9
b=8
sum=a+b
print(sum)
# Out:
# 17

# %%
a,b,c=40,78.4,"akshata"

# %%
a
# Out:
# 40

# %%
b
# Out:
# 78.4

# %%
c
# Out:
# 'akshata'
