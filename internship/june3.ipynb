# %%
sent="hello world"
sent
# Out:
# 'hello world'

# %%
sent='hello world'
sent
# Out:
# 'hello world'

# %%
sent="""
this is a docstring
it can store multiple lines
"""
print(sent)
# Out:
# this is a docstring
# it can store multiple lines

# %%
sent="hello world"
sent[0]
# Out:
# 'h'

# %%
sent[0:5]
# Out:
# 'hello'

# %%
sent=input("enter a string:")
for i in range (len(sent)):
    print(i,"->",sent[i])
# Out:
# enter a string: akshata
# 0 -> a
# 1 -> k
# 2 -> s
# 3 -> h
# 4 -> a
# 5 -> t
# 6 -> a

# %%
sent="ajit kumar;age:25;city:delhi;hobby:coding"
sent.split(";")
# Out:
# ['ajit kumar', 'age:25', 'city:delhi', 'hobby:coding']

# %%
sent.find("kumar")
# Out:
# 5

# %%
sent.find("k")
# Out:
# 5

# %%
sent.index("jit")
# Out:
# 1

# %%
l=["hello","world","python"]
" ".join(l)
# Out:
# 'hello world python'

# %%
"==".join(l)
# Out:
# 'hello==world==python'

# %%
text=input("enter a string")
l=[]
for i in text:
    l.append(i)
print(l)
# Out:
# enter a string akshata
# ['a', 'k', 's', 'h', 'a', 't', 'a']

# %%
char=input("enter a string")
letter1=input("enter a letter")
letter2=input("enter the second letter")
while 2==2:
    if letter1 in char and letter2 in char:
        print("both are present")
        break
    elif letter1 in char:
        print("only",letter1,"is present")
        break
    elif letter2 in char:
        print("only",letter2,"is present")
        break
    else:
        print("both not present")
        break
# Out:
# enter a string akshata
# enter a letter z
# enter the second letter z
# both not present

# %%
print("i like python programming\nit is easy")
# Out:
# i like python programming
# it is easy

# %%
print("i like python programming\tit is easy")
# Out:
# i like python programming	it is easy

# %%
print("i like python programming\"it is easy")
# Out:
# i like python programming"it is easy

# %%
name="ajit"
marks=85
"my name is {} and my marks are {}".format(name,marks)
# Out:
# 'my name is ajit and my marks are 85'
