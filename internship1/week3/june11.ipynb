# %%
f=open("wikipedia.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='wikipedia.txt' mode='r' encoding='cp1252'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'Wikipedia[e] is a free online encyclopedia written and maintained by a community of volunteers, known as Wikipedians, through open collaboration and the wiki software MediaWiki. Founded by Jimmy Wales and Larry Sanger in 2001, Wikipedia has been hosted since 2003 by the Wikimedia Foundation, an American nonprofit organization funded mainly by donations from readers.[1] Wikipedia is the largest and most read reference work in history.[2][3]\n'

# %%
f.readline()
# Out:
# "Initially available only in English, as of 2026, Wikipedia has grown to over 300 languages and is one of the world's most v"

# %%
f.readline()
# Out:
# ''

# %%
f=open("wikipedia.txt")

# %%
f.readline(10)
# Out:
# 'Wikipedia['

# %%
f=open("wikipedia.txt")

# %%
data=f.readlines()

# %%
for line in data:
    print(line)

# %%
f=open("wikipedia.txt")

# %%
data=f.readlines()

# %%
for line in data:
    print(line)
# Out:
# Wikipedia[e] is a free online encyclopedia written and maintained by a community of volunteers, known as Wikipedians, through open collaboration and the wiki software MediaWiki. Founded by Jimmy Wales and Larry Sanger in 2001, Wikipedia has been hosted since 2003 by the Wikimedia Foundation, an American nonprofit organization funded mainly by donations from readers.[1] Wikipedia is the largest and most read reference work in history.[2][3]
#
#
#
# Initially available only in English, as of 2026, Wikipedia has grown to over 300 languages and is one of the world's most v

# %%
for line in data:
    print(line.upper())
# Out:
# WIKIPEDIA[E] IS A FREE ONLINE ENCYCLOPEDIA WRITTEN AND MAINTAINED BY A COMMUNITY OF VOLUNTEERS, KNOWN AS WIKIPEDIANS, THROUGH OPEN COLLABORATION AND THE WIKI SOFTWARE MEDIAWIKI. FOUNDED BY JIMMY WALES AND LARRY SANGER IN 2001, WIKIPEDIA HAS BEEN HOSTED SINCE 2003 BY THE WIKIMEDIA FOUNDATION, AN AMERICAN NONPROFIT ORGANIZATION FUNDED MAINLY BY DONATIONS FROM READERS.[1] WIKIPEDIA IS THE LARGEST AND MOST READ REFERENCE WORK IN HISTORY.[2][3]
#
#
#
# INITIALLY AVAILABLE ONLY IN ENGLISH, AS OF 2026, WIKIPEDIA HAS GROWN TO OVER 300 LANGUAGES AND IS ONE OF THE WORLD'S MOST V

# %%
f.read()
# Out:
# ''

# %%
f=open("wikipedia.txt")

# %%
text=f.read()

# %%
print(text)

# %%
text.split()
# Out:
# []

# %%
f=open("wikipedia.txt")

# %%
text.split()
# Out:
# []

# %%
f=open("wikipedia.txt")

# %%
text=f.read()

# %%
print(text)
# Out:
# Wikipedia[e] is a free online encyclopedia written and maintained by a community of volunteers, known as Wikipedians, through open collaboration and the wiki software MediaWiki. Founded by Jimmy Wales and Larry Sanger in 2001, Wikipedia has been hosted since 2003 by the Wikimedia Foundation, an American nonprofit organization funded mainly by donations from readers.[1] Wikipedia is the largest and most read reference work in history.[2][3]
#
# Initially available only in English, as of 2026, Wikipedia has grown to over 300 languages and is one of the world's most v

# %%
text.split()
# Out:
# ['Wikipedia[e]',
#  'is',
#  'a',
#  'free',
#  'online',
#  'encyclopedia',
#  'written',
#  'and',
#  'maintained',
#  'by',
#  'a',
#  'community',
#  'of',
#  'volunteers,',
#  'known',
#  'as',
#  'Wikipedians,',
#  'through',
#  'open',
#  'collaboration',
#  'and',
#  'the',
#  'wiki',
#  'software',
#  'MediaWiki.',
#  'Founded',
#  'by',
#  'Jimmy',
#  'Wales',
#  'and',
#  'Larry',
#  'Sanger',
#  'in',
#  '2001,',
#  'Wikipedia',
#  'has',
#  'been',
#  'hosted',
#  'since',
#  '2003',
#  'by',
#  'the',
#  'Wikimedia',
#  'Foundation,',
#  'an',
#  'American',
#  'nonprofit',
#  'organization',
#  'funded',
#  'mainly',
#  'by',
#  'donations',
#  'from',
#  'readers.[1]',
#  'Wikipedia',
#  'is',
#  'the',
#  'largest',
#  'and',
#  'most',
#  'read',
#  'reference',
#  'work',
#  'in',
#  'history.[2][3]',
#  'Initially',
#  'available',
#  'only',
#  'in',
#  'English,',
#  'as',
#  'of',
#  '2026,',
#  'Wikipedia',
#  'has',
#  'grown',
#  'to',
#  'over',
#  '300',
# ...

# %%
m=open("marathi.txt",encoding="utf-8")

# %%
print(m.read())
# Out:
# मराठी भाषा ही इंडो-युरोपीय भाषाकुळातील एक भाषा आहे. मराठी ही भारताच्या  अधिकृत भाषांपैकी एक आहे. मराठी महाराष्ट्र राज्याची अधिकृत, तर गोवा राज्याची सह-अधिकृत भाषा आहे. च्या जनगणनेनुसार, भारतात मराठी भाषकांची एकूण लोकसंख्या सुमारे  कोटी आहे.

# %%
m.close()

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
with open("wikipedia.txt") as f:
    data=f.read()

# %%
print(data)
# Out:
# Wikipedia[e] is a free online encyclopedia written and maintained by a community of volunteers, known as Wikipedians, through open collaboration and the wiki software MediaWiki. Founded by Jimmy Wales and Larry Sanger in 2001, Wikipedia has been hosted since 2003 by the Wikimedia Foundation, an American nonprofit organization funded mainly by donations from readers.[1] Wikipedia is the largest and most read reference work in history.[2][3]
#
# Initially available only in English, as of 2026, Wikipedia has grown to over 300 languages and is one of the world's most v

# %%
f=open('myfile.txt','w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines=['frodo took  the ring.','he started his journey to mount doom.']

# %%
f.writelines(lines)

# %%
f.close()

# %%
sent="frodo took the ring.he started his journey to mount doom."

# %%
f=open('myfile.txt','w')
f.write(sent)
f.close()

# %%
s=open('wikipedia.txt','r')
f=open('myfile.txt','w')

# %%
contents=s.read()
f.write(contents)
f.close()

# %%
s=open('wikipedia.txt','a')

# %%
s.write("\ndone")
# Out:
# 5

# %%
s.close()
